# %% [markdown]
# ### Task: Build Simulation Orchestrator
# * Create a rebase and non-rebasing token and simulate a series of N deposits
# * https://docs.python.org/3/c-api/reflection.html

# %%
import os
import copy
import numpy as np
import time
import matplotlib.pyplot as plt
cwd =  os.getcwd().replace("notebooks/test","")
os.chdir(cwd)

from python.dev.math.model import TimeDeltaModel
from python.dev.math.model import TokenDeltaModel
from python.dev.simulation import SimulationOrchestrator
from python.dev.simulation import EventQueue
from python.dev.simulation import EventExecutor

from python.dev.agent import Agent
from python.dev.user import User

from python.dev.action import MintAction
from python.dev.action import DepositAction

from python.dev.event import Mint
from python.dev.event import Deposit

# %%
apy = 0.123456
target1 = Agent('T1_DEPOSIT', Agent.TYPE_TOKEN)
target2 = Agent('TCT_DEPOSIT', Agent.TYPE_TOKEN)
user = User('sim_user')
mint_event1 = Mint(10000, 0.1234567, target1, True)
mint_event2 = Mint(10000, 0.1234567, target2, False)

# %%
mint_action1 = MintAction(mint_event1,target1,user)
mint_action2 = MintAction(mint_event2,target2,user)

# %%
n_events = 100

q = EventQueue()
q.add_event(mint_action1)
q.add_event(mint_action2)

token_deltas = TokenDeltaModel(1,100).apply(n_events) 
time_deltas = TimeDeltaModel().apply(n_events)

for k in range(n_events):
    deposit_action1 = Deposit(apy, token_deltas[k], time_deltas[k])
    deposit_action2 = Deposit(apy, token_deltas[k], time_deltas[k])
    
    deposit_action1 = DepositAction(deposit_action1, target1, user)
    deposit_action2 = DepositAction(deposit_action2, target2, user)

    q.add_event(deposit_action1)
    q.add_event(deposit_action2)

# %%
orchestrator = SimulationOrchestrator()
executor = EventExecutor(q, orchestrator)
executor.run()
# Out:
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# user: sim_user target: T1_DEPOSIT
# user: sim_user target: TCT_DEPOSIT
# True
